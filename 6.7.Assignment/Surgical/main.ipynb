# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import sys
import os

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(parent_dir)

from perceptron import Perceptron

# %%
df = pd.read_csv('input/Surgical-deepnet.csv')
df
# Out:
#          bmi   Age  asa_status  baseline_cancer  baseline_charlson  \
# 0      19.31  59.2           1                1                  0
# 1      18.73  59.1           0                0                  0
# 2      21.85  59.0           0                0                  0
# 3      18.49  59.0           1                0                  1
# 4      19.70  59.0           1                0                  0
# ...      ...   ...         ...              ...                ...
# 14630  18.79  14.1           1                0                  1
# 14631  19.65  12.6           0                0                  0
# 14632  14.84  12.6           1                0                  0
# 14633  17.75   8.9           0                0                  1
# 14634  14.40   6.1           1                0                  1
#
#        baseline_cvd  baseline_dementia  baseline_diabetes  baseline_digestive  \
# 0                 0                  0                  0                   0
# ...

# %%
df.isnull().sum()
# Out:
# bmi                    0
# Age                    0
# asa_status             0
# baseline_cancer        0
# baseline_charlson      0
# baseline_cvd           0
# baseline_dementia      0
# baseline_diabetes      0
# baseline_digestive     0
# baseline_osteoart      0
# baseline_psych         0
# baseline_pulmonary     0
# ahrq_ccs               0
# ccsComplicationRate    0
# ccsMort30Rate          0
# complication_rsi       0
# dow                    0
# gender                 0
# hour                   0
# month                  0
# moonphase              0
# mort30                 0
# mortality_rsi          0
# race                   0
# complication           0
# dtype: int64

# %%
X = df.drop('complication' , axis=1).copy().values
y = df['complication'].copy().values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11708, 24), (2927, 24), (11708, 1), (2927, 1))

# %%
model = Perceptron(input_length=X_train.shape[1], learning_rate=0.001, function='sigmoid')

Loss_train, Acc_train, Loss_test, Acc_test = model.fit(X_train, y_train, X_test, y_test, epochs = 256)
# Out:
# 100%|██████████| 256/256 [00:51<00:00,  4.97it/s]

# %%
train_loss ,train_acc = model.evaluate(X_train , y_train)
print(train_loss ,train_acc)
# Out:
# 0.20317757835981243 -24.790757662590327

# %%
epochs = 256

# Plot accuracy
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(range(epochs), Acc_train, label='train')
plt.plot(range(epochs), Acc_test, label='test')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(range(epochs), Loss_train, label='train')
plt.plot(range(epochs), Loss_test, label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()

plt.tight_layout()
plt.show()
